# %% [markdown]
# Global Weather Repository

# %%
import pandas as pd
df=pd.read_csv("GlobalWeatherRepository - GlobalWeatherRepository.csv")
print(df)
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# #head

# %% [markdown]
# first 5 rows of this data

# %%
df.head
# Out:
# <bound method NDFrame.head of             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# last few rows of this data

# %%
df.tail
# Out:
# <bound method NDFrame.tail of             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# random 100 samples to understand the data

# %%
df.sample(100)
# Out:
#                       country location_name  latitude  longitude  \
# 9065    Saint Kitts and Nevis    Basseterre   17.3000   -62.7200
# 70159                   Yemen         Sanaa   15.3547    44.2067
# 58681                  Brazil          Bras   -2.0833   -58.1667
# 88724                   Gabon    Libreville    0.3833     9.4500
# 128678             Costa Rica      San Jose    9.9333   -84.0833
# ...                       ...           ...       ...        ...
# 49917                 Burundi     Bujumbura   -3.3761    29.3600
# 34101             South Korea         Seoul   37.5664   126.9997
# 18258                 Estonia       Tallinn   59.4300    24.7300
# 57660                   Syria      Damascus   33.5000    36.3000
# 10729                 Eritrea        Asmara   15.3300    38.9300
#
#                   timezone  last_updated_epoch      last_updated  \
# 9065      America/St_Kitts          1719754200   2024-06-30 9:30
# ...

# %% [markdown]
# #shape

# %% [markdown]
# to know how many rows and columns

# %%
df.shape
# Out:
# (135073, 41)

# %% [markdown]
# all columns of this data

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %% [markdown]
# #info

# %% [markdown]
# it gives a summary of the dataframa

# %%
df.info
# Out:
# <bound method DataFrame.info of             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# to see the data type of each columns

# %%
df.dtypes
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %%
df.iloc[6]
# Out:
# country                                              Argentina
# location_name                                     Buenos Aires
# latitude                                                -34.59
# longitude                                               -58.67
# timezone                        America/Argentina/Buenos_Aires
# last_updated_epoch                                  1715849100
# last_updated                                   2024-05-16 5:45
# temperature_celsius                                        8.0
# temperature_fahrenheit                                    46.4
# condition_text                                           Clear
# wind_mph                                                   2.2
# wind_kph                                                   3.6
# wind_degree                                                 10
# wind_direction                                               N
# pressure_mb                                               1014
# ...

# %% [markdown]
# keeps only the rows where condition is true

# %%
df["moon_illumination"]>10
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 135068    True
# 135069    True
# 135070    True
# 135071    True
# 135072    True
# Name: moon_illumination, Length: 135073, dtype: bool

# %%
df[(df["wind_degree"]<20)&(df["temperature_celsius"]>30)]
# Out:
#              country location_name  latitude  longitude            timezone  \
# 80              Iraq       Baghdad   33.3400    44.3900        Asia/Baghdad
# 166            Sudan      Khartoum   15.5900    32.5300     Africa/Khartoum
# 467            India     New Delhi   28.6000    77.2000        Asia/Kolkata
# 520         Pakistan     Islamabad   33.7000    73.1700        Asia/Karachi
# 715          Bolivia      National  -11.1800   -67.0800      America/La_Paz
# ...              ...           ...       ...        ...                 ...
# 132421     Indonesia       Jakarta   -6.2146   106.8451        Asia/Jakarta
# 132564  Burkina Faso   Ouagadougou   12.3703    -1.5247  Africa/Ouagadougou
# 133201     Indonesia       Jakarta   -6.2146   106.8451        Asia/Jakarta
# 133694        Tuvalu      Funafuti   -8.5167   179.2167    Pacific/Funafuti
# 134230         Palau         Koror    7.3333   134.4833       Pacific/Palau
#
# ...

# %% [markdown]
# it is used to split it

# %%
df["timezone"].str.split("/")
# Out:
# 0              [Asia, Kabul]
# 1           [Europe, Tirane]
# 2          [Africa, Algiers]
# 3          [Europe, Andorra]
# 4           [Africa, Luanda]
#                  ...
# 135068    [America, Caracas]
# 135069       [Asia, Bangkok]
# 135070          [Asia, Aden]
# 135071      [Africa, Lusaka]
# 135072      [Africa, Harare]
# Name: timezone, Length: 135073, dtype: object

# %%
df["location_name"].value_counts()
# Out:
# location_name
# Kabul        695
# Sanaa        695
# Suva         695
# Accra        695
# Kyiv         695
#             ...
# Pristina       1
# Asuncion       1
# Palau          1
# Bali           1
# Sao Paulo      1
# Name: count, Length: 257, dtype: int64

# %% [markdown]
# it is uesd to detect the missing vaue in the dataset

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %% [markdown]
# sort in accenting order(small to big )

# %%
df.sort_values(by="temperature_celsius")
# Out:
#          country location_name  latitude  longitude          timezone  \
# 118990  Mongolia   Ulaanbaatar   47.9167   106.9167  Asia/Ulaanbaatar
# 119182  Mongolia   Ulaanbaatar   47.9167   106.9167  Asia/Ulaanbaatar
# 121617   Belarus         Minsk   53.9000    27.5667      Europe/Minsk
# 118606  Mongolia   Ulaanbaatar   47.9167   106.9167  Asia/Ulaanbaatar
# 118801  Mongolia   Ulaanbaatar   47.9167   106.9167  Asia/Ulaanbaatar
# ...          ...           ...       ...        ...               ...
# 85049     Kuwait   Kuwait City   29.3667    47.9600       Asia/Kuwait
# 8425      Kuwait   Kuwait City   29.3700    47.9600       Asia/Kuwait
# 11145       Iraq       Baghdad   33.3400    44.3900      Asia/Baghdad
# 7460        Iraq       Baghdad   33.3400    44.3900      Asia/Baghdad
# 6896      Kuwait   Kuwait City   29.3700    47.9600       Asia/Kuwait
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
df["timezone"]=df["timezone"].str.replace("+","")

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# clear date and time in last_update

# %%
df['last_updated']=pd.to_datetime(df["last_updated"])

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# for a clean columns

# %%
df.columns=df.columns.str.strip().str.lower()

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
print(df.head())
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch        last_updated  temperature_celsius  \
# 0          1715849100 2024-05-16 13:15:00                 26.6
# 1          1715849100 2024-05-16 10:45:00                 19.0
# 2          1715849100 2024-05-16 09:45:00                 23.0
# 3          1715849100 2024-05-16 10:45:00                  6.3
# 4          1715849100 2024-05-16 09:45:00                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_pm2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %% [markdown]
# to know maximum ,minimum ,std..

# %%
df.describe()
# Out:
#             latitude      longitude  last_updated_epoch  \
# count  135073.000000  135073.000000        1.350730e+05
# mean       19.208948      21.961711        1.745908e+09
# min       -41.300000    -175.200000        1.715849e+09
# 25%         4.050300      -6.836100        1.730970e+09
# 50%        17.250000      23.236100        1.745916e+09
# 75%        40.400000      49.882200        1.760860e+09
# max        64.150000     179.220000        1.775975e+09
# std        24.416748      65.787645        1.734686e+07
#
#                         last_updated  temperature_celsius  \
# count                         135073        135073.000000
# mean   2025-04-29 08:31:05.284698112            21.283607
# min              2024-05-16 01:45:00           -29.800000
# 25%              2024-11-07 05:00:00            16.000000
# 50%              2025-04-29 10:45:00            24.000000
# 75%              2025-10-19 13:45:00            28.000000
# ...

# %% [markdown]
# seperate date and time in last_updated

# %%
df['last_updated']=pd.to_datetime(df['last_updated'],errors='coerce')

# %%
df['date']=df['last_updated'].dt.date

# %%
df['time']=df['last_updated'].dt.time

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# it is split the timezone to two columns continent and city

# %%
df['timezone']=df['timezone'].fillna('unknown/unknown')

# %%
split_columns=df['timezone'].str.split('/',n=1,expand=True)

# %%
df['continent']=split_columns[0]

# %%
df['city']=split_columns[1]

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %% [markdown]
# to seperate day and month in date

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['month']=df['date'].dt.month

# %%
df['day']=df['date'].dt.day

# %%
df['year']=df['date'].dt.year

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.to_csv("cleaned_data.csv")

# %%
df
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...
